# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5e7948df-674d-460b-9d9e-8c138e24b06b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e7948df-674d-460b-9d9e-8c138e24b06b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
temps_df = pd.read_csv('long_format_annual_surface_temp.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-918bde4c-bf7a-4174-90d4-34b94c8da8f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-918bde4c-bf7a-4174-90d4-34b94c8da8f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
urban_df = pd.read_csv('global_urbanization_climate_metrics.csv')

# %%
temps_df
# Out:
#                             Country ISO2   Year  Temperature
# 0      Afghanistan, Islamic Rep. of   AF  F1961       -0.113
# 1                           Albania   AL  F1961        0.627
# 2                           Algeria   DZ  F1961        0.164
# 3                    American Samoa   AS  F1961        0.079
# 4          Andorra, Principality of   AD  F1961        0.736
# ...                             ...  ...    ...          ...
# 11217            West Bank and Gaza   PS  F2022        1.074
# 11218                Western Sahara   EH  F2022        1.970
# 11219                         World   ZM  F2022        1.394
# 11220                        Zambia   ZM  F2022        0.686
# 11221                      Zimbabwe   ZW  F2022       -0.490
#
# [11222 rows x 4 columns]

# %%
urban_df
# Out:
#                            country country_code  year    total_pop  \
# 0                            Aruba          ABW  1960      54922.0
# 1      Africa Eastern and Southern          AFE  1960  130072080.0
# 2                      Afghanistan          AFG  1960    9035043.0
# 3       Africa Western and Central          AFW  1960   97630925.0
# 4                           Angola          AGO  1960    5231654.0
# ...                            ...          ...   ...          ...
# 17019                       Kosovo          XKX  2023    1756366.0
# 17020                  Yemen, Rep.          YEM  2023   39390799.0
# 17021                 South Africa          ZAF  2023   63212384.0
# 17022                       Zambia          ZMB  2023   20723965.0
# 17023                     Zimbabwe          ZWE  2023   16340822.0
#
#        pop_dens_sq_km           gdp  urban_pop_perc  rural_pop_perc  \
# 0                 NaN           NaN       50.776000       49.224000
# ...

# %%
temps_df['Year'] = temps_df['Year'].apply(lambda x: x[1:])

# %%
temps_df
# Out:
#                             Country ISO2  Year  Temperature
# 0      Afghanistan, Islamic Rep. of   AF  1961       -0.113
# 1                           Albania   AL  1961        0.627
# 2                           Algeria   DZ  1961        0.164
# 3                    American Samoa   AS  1961        0.079
# 4          Andorra, Principality of   AD  1961        0.736
# ...                             ...  ...   ...          ...
# 11217            West Bank and Gaza   PS  2022        1.074
# 11218                Western Sahara   EH  2022        1.970
# 11219                         World   ZM  2022        1.394
# 11220                        Zambia   ZM  2022        0.686
# 11221                      Zimbabwe   ZW  2022       -0.490
#
# [11222 rows x 4 columns]

# %%
for country in temps_df['Country']:
  country_df = temps_df[temps_df['Country'] == country]
  temps_df[temps_df['Country'] == country]['Temps_Change'] = country_df[country_df['Year'] == '2022']['Temperature'].iloc[0] - country_df[country_df['Year'] == '2000']['Temperature'].iloc[0]
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps_df[temps_df['Country'] == country]['Temps_Change'] = country_df[country_df['Year'] == '2022']['Temperature'].iloc[0] - country_df[country_df['Year'] == '2000']['Temperature'].iloc[0]
# <ipython-input-57-a95af42cf7b7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps_df[temps_df['Country'] == country]['Temps_Change'] = country_df[country_df['Year'] == '2022']['Temperature'].iloc[0] - country_df[country_df['Year'] == '2000']['Temperature'].iloc[0]
# <ipython-input-57-a95af42cf7b7>:3: SettingWithCopyWarning:
# ...

# %%
country_df = temps_df[temps_df['Country'] == 'Albania']
country_df['Temps_Change'] = country_df[country_df['Year'] == '2022']['Temperature'].iloc[0] - country_df[country_df['Year'] == '2000']['Temperature'].iloc[0]
country_df
# Out:
# <ipython-input-55-59556b06ba88>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_df['Temps_Change'] = country_df[country_df['Year'] == '2022']['Temperature'].iloc[0] - country_df[country_df['Year'] == '2000']['Temperature'].iloc[0]
#        Country ISO2  Year  Temperature  Temps_Change
# 1      Albania   AL  1961        0.627         0.453
# 182    Albania   AL  1962        0.326         0.453
# 363    Albania   AL  1963        0.075         0.453
# 544    Albania   AL  1964       -0.166         0.453
# 725    Albania   AL  1965       -0.388         0.453
# ...        ...  ...   ...          ...           ...
# 10318  Albania   AL  2018        2.028         0.453
# 10499  Albania   AL  2019        1.675         0.453
# ...

# %%
temps_df[temps_df['Country'] == 'Albania']
# Out:
#        Country ISO2  Year  Temperature
# 1      Albania   AL  1961        0.627
# 182    Albania   AL  1962        0.326
# 363    Albania   AL  1963        0.075
# 544    Albania   AL  1964       -0.166
# 725    Albania   AL  1965       -0.388
# ...        ...  ...   ...          ...
# 10318  Albania   AL  2018        2.028
# 10499  Albania   AL  2019        1.675
# 10680  Albania   AL  2020        1.498
# 10861  Albania   AL  2021        1.536
# 11042  Albania   AL  2022        1.518
#
# [62 rows x 4 columns]

# %%
temps_df[temps_df['Year'] == '2000' & temps_df['Country'] == 'Albania']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     361         #  (xint or xbool) and (yint or bool)
# --> 362         result = op(x, y)
#     363     except TypeError:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/roperator.py in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#      55
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     375             try:
# --> 376                 result = libops.scalar_binop(x, y, op)
#     377             except (
# ...
